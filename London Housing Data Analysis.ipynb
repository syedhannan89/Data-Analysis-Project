# %%
import pandas as pd

# %%
london = pd.read_csv(r"C:\Users\DC\Downloads\5. London Housing Data.csv")

# %%
london
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
london.isnull().sum() # find the no of nulls
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
london.count() # no of count in each columns
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(london.isnull()) #heatmap of null values

# %%
london.dtypes #data types of each columns
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
london.date = pd.to_datetime(london.date) #converting date datatype to datetime datatype

# %%
london.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
london['year'] = london.date.dt.year #creating the year from the date column

# %%
london
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
london['month'] = london.date.dt.month #creating the month from the date column

# %%
london
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year  month
# 0               NaN  1995      1
# 1               NaN  1995      2
# ...

# %%
london.insert(2,'day',london.date.dt.day) #creating the day from the date column

# %%
london
# Out:
#             date            area  day  average_price       code  houses_sold  \
# 0     1995-01-01  city of london    1          91449  E09000001         17.0
# 1     1995-02-01  city of london    1          82203  E09000001          7.0
# 2     1995-03-01  city of london    1          79121  E09000001         14.0
# 3     1995-04-01  city of london    1          77101  E09000001          7.0
# 4     1995-05-01  city of london    1          84409  E09000001         10.0
# ...          ...             ...  ...            ...        ...          ...
# 13544 2019-09-01         england    1         249942  E92000001      64605.0
# 13545 2019-10-01         england    1         249376  E92000001      68677.0
# 13546 2019-11-01         england    1         248515  E92000001      67814.0
# 13547 2019-12-01         england    1         250410  E92000001          NaN
# 13548 2020-01-01         england    1         247355  E92000001          NaN
#
#        no_of_crimes  year  month
# ...

# %%
london.drop(['day', 'month', 'year'], axis = 1, inplace = True) #deleting day, month & year

# %%
london
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
london[london.no_of_crimes == 0] #find the values where no of crimes is zero
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
london[london.area == 'city of london'] #find the value of area where area is equal to city of london
# Out:
#           date            area  average_price       code  houses_sold  \
# 0   1995-01-01  city of london          91449  E09000001         17.0
# 1   1995-02-01  city of london          82203  E09000001          7.0
# 2   1995-03-01  city of london          79121  E09000001         14.0
# 3   1995-04-01  city of london          77101  E09000001          7.0
# 4   1995-05-01  city of london          84409  E09000001         10.0
# ..         ...             ...            ...        ...          ...
# 296 2019-09-01  city of london         792034  E09000001         11.0
# 297 2019-10-01  city of london         827093  E09000001          4.0
# 298 2019-11-01  city of london         777610  E09000001          5.0
# 299 2019-12-01  city of london         734872  E09000001          NaN
# 300 2020-01-01  city of london         775309  E09000001          NaN
#
#      no_of_crimes
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...

# %%
len(london[london.no_of_crimes == 0]) # Sum of all values where no of crimes is zero
# Out:
# 104

# %%
london['year'] = london.date.dt.year

# %%
london
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
london[london.area =='england'] # value where area is england
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-09-01  england         249942  E92000001      64605.0
# 13545 2019-10-01  england         249376  E92000001      68677.0
# 13546 2019-11-01  england         248515  E92000001      67814.0
# 13547 2019-12-01  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# 13250           NaN  1995
# 13251           NaN  1995
# 13252           NaN  1995
# ...

# %%
london.groupby('year').average_price.max() # max avg price by year
# Out:
# year
# 1995     200722
# 1996     223197
# 1997     265112
# 1998     277600
# 1999     354241
# 2000     397353
# 2001     451028
# 2002     497538
# 2003     488704
# 2004     559286
# 2005     555847
# 2006     644541
# 2007     830950
# 2008     832753
# 2009     782459
# 2010     884674
# 2011     959520
# 2012    1077366
# 2013    1217729
# 2014    1365050
# 2015    1353679
# 2016    1357231
# 2017    1412255
# 2018    1463378
# 2019    1294113
# 2020    1178166
# Name: average_price, dtype: int64

# %%
london.groupby('year').average_price.min() # min avg price by year
# Out:
# year
# 1995     41688
# 1996     40722
# 1997     42353
# 1998     43510
# 1999     43969
# 2000     47604
# 2001     49045
# 2002     54746
# 2003     67520
# 2004     88520
# 2005    110454
# 2006    121124
# 2007    131175
# 2008    120275
# 2009    117079
# 2010    119688
# 2011    115328
# 2012    113011
# 2013    112008
# 2014    114531
# 2015    117156
# 2016    121085
# 2017    121858
# 2018    124038
# 2019    124567
# 2020    126592
# Name: average_price, dtype: int64

# %%
london.groupby('area').no_of_crimes.max() # max avg crime by area
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
london.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %%
london.groupby('area').average_price.min().sort_values(ascending = False)
# Out:
# area
# kensington and chelsea    182345
# westminster               131468
# hammersmith and fulham    120636
# camden                    115419
# richmond upon thames      106875
# barnet                     90107
# islington                  89406
# wandsworth                 86518
# harrow                     82054
# bromley                    81124
# kingston upon thames       80876
# merton                     79569
# ealing                     79272
# city of london             77101
# haringey                   76288
# inner london               75886
# london                     72778
# outer london               72592
# redbridge                  72142
# hillingdon                 71760
# brent                      71307
# hounslow                   71052
# enfield                    70631
# sutton                     69291
# croydon                    68006
# havering                   66182
# lambeth                    65382
# bexley                     63723
# ...

# %%
london.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %%
london[london.average_price > 10000].area.value_counts() #area where avg price is less than 10000
# Out:
# tower hamlets             302
# hackney                   302
# enfield                   302
# south east                302
# city of london            301
# east midlands             301
# greenwich                 301
# islington                 301
# sutton                    301
# lewisham                  301
# brent                     301
# wandsworth                301
# hillingdon                301
# outer london              301
# newham                    301
# bexley                    301
# kingston upon thames      301
# camden                    301
# redbridge                 301
# inner london              301
# north east                301
# hammersmith and fulham    301
# merton                    301
# london                    301
# croydon                   301
# southwark                 301
# east of england           301
# harrow                    301
# lambeth                   301
# barnet                    301
# barking and dagenham      301
# ...

# %%
london.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %%
london[london.average_price > 100000].area.value_counts()
# Out:
# richmond upon thames      301
# hammersmith and fulham    301
# camden                    301
# kensington and chelsea    301
# westminster               301
# city of london            290
# islington                 282
# barnet                    276
# wandsworth                275
# harrow                    271
# kingston upon thames      271
# inner london              270
# ealing                    270
# bromley                   268
# haringey                  268
# merton                    266
# london                    262
# brent                     261
# hounslow                  260
# lambeth                   260
# hillingdon                257
# outer london              255
# tower hamlets             255
# southwark                 253
# hackney                   249
# redbridge                 249
# enfield                   248
# sutton                    247
# croydon                   244
# south east                243
# greenwich                 242
# ...
